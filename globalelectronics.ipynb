# %%
import pandas as pd

# %%
customers = pd.read_csv('customers.csv',encoding='ISO-8859-1')
sales = pd.read_csv('sales.csv',encoding='ISO-8859-1')
products = pd.read_csv('products.csv',encoding='ISO-8859-1')
stores = pd.read_csv('stores.csv',encoding='ISO-8859-1')
currency_exchange = pd.read_csv('Exchange_Rates.csv',encoding='ISO-8859-1')

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales.dtypes
# Out:
# Order Number      int64
# Line Item         int64
# Order Date       object
# Delivery Date    object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object

# %%
sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaT       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20           NaT      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
sales['Order Date'] = pd.to_datetime(sales['Order Date'],format = '%m/%d/%Y')
sales['Delivery Date'] = pd.to_datetime(sales['Delivery Date'],format = '%m/%d/%Y',errors='coerce')
sales['Currency Code'] = sales['Currency Code'].astype(str)

# %%
sales.fillna('Not Available' , inplace = True)
sales
# Out:
# C:\Users\ashok\AppData\Local\Temp\ipykernel_14588\2455216390.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Available' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   sales.fillna('Not Available' , inplace = True)
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01        Not Available       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20        Not Available      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
stores
# Out:
#     storekey        country                         state  square_meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     open_date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09
# ..        ...
# 62 2008-03-06
# 63 2010-01-01
# 64 2012-01-01
# 65 2014-01-01
# 66 2010-01-01
#
# [67 rows x 5 columns]

# %%
stores.isnull().sum()
# Out:
# storekey         0
# country          0
# state            0
# square_meters    0
# open_date        0
# dtype: int64

# %%
stores.dtypes
# Out:
# storekey                  int64
# country                  object
# state                    object
# square_meters           float64
# open_date        datetime64[ns]
# dtype: object

# %%
stores.fillna(0,inplace=True)

# %%
stores.dtypes
# Out:
# storekey                  int64
# country                  object
# state                    object
# square_meters           float64
# open_date        datetime64[ns]
# dtype: object

# %%
stores['Country']=stores['Country'].astype(str)
stores['State']=stores['State'].astype(str)
stores['Open Date']=pd.to_datetime(stores['Open Date'], format='%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 stores['Country']=stores['Country'].astype(str)
#       2 stores['State']=stores['State'].astype(str)
#       3 stores['Open Date']=pd.to_datetime(stores['Open Date'], format='%m/%d/%Y')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Country'

# %%
stores

# %%
products.isnull().sum()

# %%
products

# %%
products['Unit Cost USD'] = products['Unit Cost USD'].replace('[\$,]','',regex=True).astype(float)
products['Unit Price USD'] = products['Unit Price USD'].replace('[\$,]','',regex=True).astype(float)

# %%
products.dtypes

# %%
products

# %%
customers.isnull().sum()

# %%
customers.dtypes

# %%
def convert_date(date_str):
    try:
        return pd.to_datetime(date_str, format='%m/%d/%Y' , errors='coerce' ).strftime('%m/%d/%Y')
    except ValueError:
        return date_str
customers['Birthday'] = customers['Birthday'].apply(convert_date)

# %%
customers['State Code'].fillna('Not Available',inplace=True)
# Out:
# C:\Users\ashok\AppData\Local\Temp\ipykernel_14588\115889270.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers['State Code'].fillna('Not Available',inplace=True)

# %%
customers['Birthday'] = pd.to_datetime(customers['Birthday'], format='%m/%d/%Y' , errors='coerce' )

# %%
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent   Birthday
# 0        South Australia     5523      Australia      Australia 1939-07-03
# 1      Western Australia     6522      Australia      Australia 1979-09-27
# 2               Victoria     3380      Australia      Australia 1947-05-26
# 3        South Australia     5223      Australia      Australia 1957-09-17
# 4               Victoria     3698      Australia      Australia 1965-11-19
# ...                  ...      ...            ...            ...        ...
# 15261              Texas    77017  United States  North America 1936-03-25
# 15262           Virginia    22101  United States  North America 1992-02-16
# 15263     North Carolina    28405  United States  North America 1937-11-09
# 15264         California    92501  United States  North America 1937-10-12
# 15265           Michigan    48302  United States  North America 1965-08-18
#
# [15266 rows x 10 columns]

# %%
currency_exchange.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
currency_exchange.dtypes
# Out:
# Date        datetime64[ns]
# Currency            object
# Exchange           float64
# dtype: object

# %%
currency_exchange
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
sales
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01        Not Available       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20        Not Available      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent   Birthday
# 0        South Australia     5523      Australia      Australia 1939-07-03
# 1      Western Australia     6522      Australia      Australia 1979-09-27
# 2               Victoria     3380      Australia      Australia 1947-05-26
# 3        South Australia     5223      Australia      Australia 1957-09-17
# 4               Victoria     3698      Australia      Australia 1965-11-19
# ...                  ...      ...            ...            ...        ...
# 15261              Texas    77017  United States  North America 1936-03-25
# 15262           Virginia    22101  United States  North America 1992-02-16
# 15263     North Carolina    28405  United States  North America 1937-11-09
# 15264         California    92501  United States  North America 1937-10-12
# 15265           Michigan    48302  United States  North America 1965-08-18
#
# [15266 rows x 10 columns]

# %%
overall=sales

# %%
overall = pd.merge(overall,customers,on='CustomerKey',how='inner')

# %%
overall.dropna(inplace=True)

# %%
overall
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01        Not Available       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20        Not Available      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  \
# 0            10        1304         1           CAD    Male
# 1             0        1048         2           USD    Male
# 2             0        2007         1           USD    Male
# 3             0        1106         7           CAD  Female
# 4             0         373         1           CAD  Female
# ...         ...         ...       ...           ...     ...
# 62879        43         632         3           USD    Male
# 62880         0          98         4           EUR  Female
# 62881         0        1613         2           CAD    Male
# 62882         0        1717         2           CAD    Male
# 62883         0         464         7           CAD    Male
#
#                     Name                  City State Code              State  \
# 0           Tyler Vaught                London         ON            Ontario
# 1         Frank Upchurch               Auberry         CA         California
# 2         Frank Upchurch               Auberry         CA         California
# 3             Joan Roche              Red Deer         AB            Alberta
# 4             Joan Roche              Red Deer         AB            Alberta
# ...                  ...                   ...        ...                ...
# 62879      Donald Woodie          Garden Grove         CA         California
# 62880  Gabriele Thalberg  Stuttgart Frauenkopf         BW  Baden-Württemberg
# 62881   William Rochelle               Calgary         AB            Alberta
# 62882   William Rochelle               Calgary         AB            Alberta
# 62883   William Rochelle               Calgary         AB            Alberta
#
#       Zip Code        Country      Continent   Birthday
# 0      N5W 5K6         Canada  North America 1971-03-23
# 1        93602  United States  North America 1995-11-20
# 2        93602  United States  North America 1995-11-20
# 3      T4N 2A6         Canada  North America 1962-08-24
# 4      T4N 2A6         Canada  North America 1962-08-24
# ...        ...            ...            ...        ...
# 62879    92643  United States  North America 1939-04-16
# 62880    70184        Germany         Europe 1940-03-10
# 62881  T2T 0C6         Canada  North America 1993-05-25
# 62882  T2T 0C6         Canada  North America 1993-05-25
# 62883  T2T 0C6         Canada  North America 1993-05-25
#
# [62884 rows x 18 columns]

# %%
# Convert the 'Date' column in currency_exchange to datetime64[ns]
currency_exchange['Date'] = pd.to_datetime(currency_exchange['Date'])

# Now perform the merge
overall = pd.merge(overall, currency_exchange, left_on=['Order Date', 'Currency Code'], right_on=['Date', 'Currency'], how='inner')

# %%
overall=pd.merge(overall, products , on='ProductKey',how='inner' )

# %%
overall=pd.merge(overall,stores,on=['StoreKey','Country','State'],how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14588\2805340846.py in ?()
# ----> 1 overall=pd.merge(overall,stores,on=['StoreKey','Country','State'],how='inner')
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'StoreKey'

# %%
overall

# %%
col= list(overall.columns)
col1=[]
for c in col:
    col1.append(c.replace(' ','_').lower())
overall.columns=col1

# %%
col= list(stores.columns)
col1=[]
for c in col:
    col1.append(c.replace(' ','_').lower())
stores.columns=col1

# %%
col1

# %%
overall.columns

# %%
overall.isnull().sum()

# %%
overall.dtypes
# Out:
# Order Number               int64
# Line Item                  int64
# Order Date        datetime64[ns]
# Delivery Date             object
# CustomerKey                int64
# StoreKey                   int64
# ProductKey                 int64
# Quantity                   int64
# Currency Code             object
# Gender                    object
# Name                      object
# City                      object
# State Code                object
# State                     object
# Zip Code                  object
# Country                   object
# Continent                 object
# Birthday          datetime64[ns]
# Date              datetime64[ns]
# Currency                  object
# Exchange                 float64
# Product Name              object
# Brand                     object
# Color                     object
# Unit Cost USD            float64
# Unit Price USD           float64
# SubcategoryKey             int64
# Subcategory               object
# CategoryKey                int64
# Category                  object
# dtype: object

# %%
overall[['order_date','date','currency_code','currency','customerkey']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 overall[['order_date','date','currency_code','currency','customerkey']]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['order_date', 'date', 'currency_code', 'currency', 'customerkey'], dtype='object')] are in the [columns]"

# %%
overall.to_csv('alldatas.csv')

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

user = 'root'
password = 'ashokV'
host = 'localhost'  # or your MySQL server host
database = 'global_electronics'

# Create an engine instance
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{database}')

# Transfer DataFrame to MySQL table
try:
    # Convert DataFrame to MySQL table
    overall.to_sql('all_data', engine, if_exists='replace', index=False)
    print("Data transfer to MySQL was successful.")

    customers.to_sql('customers', engine, if_exists='replace', index=False)
    print("Data transfer to MySQL was successful.")
    products.to_sql('products', engine, if_exists='replace', index=False)
    print("Data transfer to MySQL was successful.")
    currency_exchange.to_sql('currency_exchange', engine, if_exists='replace', index=False)
    print("Data transfer to MySQL was successful.")
    stores.to_sql('stores', engine, if_exists='replace', index=False)
    print("Data transfer to MySQL was successful.")
    sales.to_sql('sales', engine, if_exists='replace', index=False)
    print("Data transfer to MySQL was successful.")
    
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data transfer to MySQL was successful.
# Data transfer to MySQL was successful.
# Data transfer to MySQL was successful.
# Data transfer to MySQL was successful.
# Data transfer to MySQL was successful.
# Data transfer to MySQL was successful.
